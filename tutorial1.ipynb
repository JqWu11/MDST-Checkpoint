# %% [markdown]
# # ML Walkthrough

# %% [markdown]
# We spend a lot of money on education every year! In general, we believe that the more we spend, the better our schools are and the better our students perform. But do we really know that?
#
# To adress these questions, we will spend today looking at a US education dataset and see what we can learn about indicators of student performance. In particular, we want to answer the question: what are useful indicators to predict student performance on national exams?

# %% [markdown]
# ## Data Poking

# %% [markdown]
# We start off by importing our data and seeing what we've got:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Suppress Pandas SettingWithCopyWarning
pd.options.mode.chained_assignment = None

# %%
df = pd.read_csv('states_edu.csv')

# %%
df.shape
# Out:
# (0, 43040)

# %% [markdown]
# We are given that this dataset describes "K-12 financial, enrollment, and achievement data in one place". Each row is one state in one year, and includes variables for revenue categories, expenditure types, enrollment numbers, and exam scores.

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [{"payload":{"allShortcutsEnabled":true, fileTree:{"data":{"items":[{"name":"cereal.csv", path:"data/cereal.csv", contentType:"file"}, {"name":"starbucks.csv", path:"data/starbucks.csv", contentType:"file"}.1, {"name":"states_edu.csv", path:"data/states_edu.csv", contentType:"file"}], totalCount:3}, :{"items":[{"name":"Data-Visualization", path:"Data-Visualization", contentType:"directory"}, {"name":"Optional Challenges", path:"Optional Challenges", contentType:"directory"}.1, {"name":"data", path:"data", contentType:"directory"}.2, {"name":"tutorial0", path:"tutorial0", contentType:"directory"}.3, {"name":"tutorial1", path:"tutorial1", contentType:"directory"}.4, {"name":".gitignore", path:".gitignore", contentType:"file"}.2, {"name":"README.md", path:"README.md", contentType:"file"}.3, {"name":"requirements.txt", path:"requirements.txt", contentType:"file"}].1, totalCount:8}}, fileTreeProcessingTime:10.429732000000001, foldersToFetch:[], reducedMotionEnabled:"system", repo:{"id":529869678, defaultBranch:"main", name:"2023-Tutorials", ownerLogin:"MichiganDataScienceTeam", currentUserCanPush:false, isFork:false, isEmpty:false, createdAt:"2022-08-28T09:25:18.000-04:00", ownerAvatar:"https://avatars.githubusercontent.com/u/15266139?v=4", public:true, private:false, isOrgOwned:true}, symbolsExpanded:false, treeExpanded:true, refInfo:{"name":"b79043e8eed2e57606c2aab37ec1f867a8b429e6", listCacheKey:"v0:1705247162.0", canEdit:false, refType:"tree", currentOid:"b79043e8eed2e57606c2aab37ec1f867a8b429e6"}, path:"data/states_edu.csv".1, currentUser:{"id":153706586, login:"JqWu11", userEmail:"jqwu@umich.edu"}, blob:{"rawLines":null, stylingDirectives:null, csv:[["PRIMARY_KEY", STATE, YEAR, ENROLL, TOTAL_REVENUE, FEDERAL_REVENUE, STATE_REVENUE, LOCAL_REVENUE, TOTAL_EXPENDITURE, INSTRUCTION_EXPENDITURE, SUPPORT_SERVICES_EXPENDITURE, OTHER_EXPENDITURE, CAPITAL_OUTLAY_EXPENDITURE, GRADES_PK_G, GRADES_KG_G, GRADES_4_G, GRADES_8_G, GRADES_12_G, GRADES_1_8_G, GRADES_9_12_G, GRADES_ALL_G, AVG_MATH_4_SCORE, AVG_MATH_8_SCORE, AVG_READING_4_SCORE, AVG_READING_8_SCORE], ["1992_ALABAMA", ALABAMA, 1992, null, 2678885.0, 304177.0, 1659028.0, 715680.0, 2653798.0, 1481703.0, 735036.0, ...]
# Index: []
#
# [0 rows x 43040 columns]

# %%
df.columns
# Out:
# Index(['{"payload":{"allShortcutsEnabled":true',
#        'fileTree:{"data":{"items":[{"name":"cereal.csv"',
#        'path:"data/cereal.csv"', 'contentType:"file"}',
#        '{"name":"starbucks.csv"', 'path:"data/starbucks.csv"',
#        'contentType:"file"}.1', '{"name":"states_edu.csv"',
#        'path:"data/states_edu.csv"', 'contentType:"file"}]',
#        ...
#        'viewable:true', 'workflowRedirectUrl:null',
#        'symbols:{"timed_out":false', 'not_analyzed:true', 'symbols:[]}}',
#        'copilotInfo:null', 'copilotAccessAllowed:false',
#        'csrf_tokens:{"/MichiganDataScienceTeam/2023-Tutorials/branches":{"post":"Bcc4XB4ZDzfnCDelbkaGVdo58wCq_Fr1Y9yBWT0vIjEd1RuHvOs-1M-K29uWOqOlhV9r3dPRvjzb7MSZ7S4_0w"}',
#        '/repos/preferences:{"post":"iNJX745XYh_3eHmuSThrQNv6CKGDFAwyUoLKfCEazXfuFUoO55vUFTGPpbjpdUZ8NjZNG2li_9K1x8UexXvpng"}}}',
#        'title:"2023-Tutorials/data/states_edu.csv at b79043e8eed2e57606c2aab37ec1f867a8b429e6 · MichiganDataScienceTeam/2023-Tutorials"}'],
#       dtype='object', length=43040)

# %% [markdown]
# ## Data Cleanup

# %%
# let's rename our columns to make them more intuitive
df.rename({
    'GRADES_PK_G':'ENROLL_PREK',
    'GRADES_KG_G':'ENROLL_KINDER',
    'GRADES_4_G':'ENROLL_4',
    'GRADES_8_G':'ENROLL_8',
    'GRADES_12_G':'ENROLL_12',
    'GRADES_1_8_G':'ENROLL_PRIMARY',
    'GRADES_9_12_G':'ENROLL_HS',
    'GRADES_ALL_G':'ENROLL_ALL',
    'ENROLL':'ENROLL_ALL_EST'
    },
    axis=1,inplace=True)
#inplace return copy of dataframe

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [{"payload":{"allShortcutsEnabled":true, fileTree:{"data":{"items":[{"name":"cereal.csv", path:"data/cereal.csv", contentType:"file"}, {"name":"starbucks.csv", path:"data/starbucks.csv", contentType:"file"}.1, {"name":"states_edu.csv", path:"data/states_edu.csv", contentType:"file"}], totalCount:3}, :{"items":[{"name":"Data-Visualization", path:"Data-Visualization", contentType:"directory"}, {"name":"Optional Challenges", path:"Optional Challenges", contentType:"directory"}.1, {"name":"data", path:"data", contentType:"directory"}.2, {"name":"tutorial0", path:"tutorial0", contentType:"directory"}.3, {"name":"tutorial1", path:"tutorial1", contentType:"directory"}.4, {"name":".gitignore", path:".gitignore", contentType:"file"}.2, {"name":"README.md", path:"README.md", contentType:"file"}.3, {"name":"requirements.txt", path:"requirements.txt", contentType:"file"}].1, totalCount:8}}, fileTreeProcessingTime:10.429732000000001, foldersToFetch:[], reducedMotionEnabled:"system", repo:{"id":529869678, defaultBranch:"main", name:"2023-Tutorials", ownerLogin:"MichiganDataScienceTeam", currentUserCanPush:false, isFork:false, isEmpty:false, createdAt:"2022-08-28T09:25:18.000-04:00", ownerAvatar:"https://avatars.githubusercontent.com/u/15266139?v=4", public:true, private:false, isOrgOwned:true}, symbolsExpanded:false, treeExpanded:true, refInfo:{"name":"b79043e8eed2e57606c2aab37ec1f867a8b429e6", listCacheKey:"v0:1705247162.0", canEdit:false, refType:"tree", currentOid:"b79043e8eed2e57606c2aab37ec1f867a8b429e6"}, path:"data/states_edu.csv".1, currentUser:{"id":153706586, login:"JqWu11", userEmail:"jqwu@umich.edu"}, blob:{"rawLines":null, stylingDirectives:null, csv:[["PRIMARY_KEY", STATE, YEAR, ENROLL_ALL_EST, TOTAL_REVENUE, FEDERAL_REVENUE, STATE_REVENUE, LOCAL_REVENUE, TOTAL_EXPENDITURE, INSTRUCTION_EXPENDITURE, SUPPORT_SERVICES_EXPENDITURE, OTHER_EXPENDITURE, CAPITAL_OUTLAY_EXPENDITURE, ENROLL_PREK, ENROLL_KINDER, ENROLL_4, ENROLL_8, ENROLL_12, ENROLL_PRIMARY, ENROLL_HS, ENROLL_ALL, AVG_MATH_4_SCORE, AVG_MATH_8_SCORE, AVG_READING_4_SCORE, AVG_READING_8_SCORE], ["1992_ALABAMA", ALABAMA, 1992, null, 2678885.0, 304177.0, 1659028.0, 715680.0, 2653798.0, 1481703.0, 735036.0, ...]
# Index: []
#
# [0 rows x 43040 columns]

# %% [markdown]
# Looking closer at the data, there are a lot of 'NaN' values... what are those?

# %%
# this is a numpy value which represents missnig or invalid data (not-a-number)
np.NaN
# Out:
# nan

# %%
# it is treated as a float, so it is easily compatible with numpy and pandas
type(np.NaN)
# Out:
# float

# %% [markdown]
# We can easily find and describe missing values with `pandas`.

# %%
# this will print the number of missing values in each column
df.isna().sum()
# Out:
# {"payload":{"allShortcutsEnabled":true                                                                                                                               0
# fileTree:{"data":{"items":[{"name":"cereal.csv"                                                                                                                      0
# path:"data/cereal.csv"                                                                                                                                               0
# contentType:"file"}                                                                                                                                                  0
# {"name":"starbucks.csv"                                                                                                                                              0
#                                                                                                                                                                     ..
# copilotAccessAllowed:false                                                                                                                                           0
# csrf_tokens:{"/MichiganDataScienceTeam/2023-Tutorials/branches":{"post":"Bcc4XB4ZDzfnCDelbkaGVdo58wCq_Fr1Y9yBWT0vIjEd1RuHvOs-1M-K29uWOqOlhV9r3dPRvjzb7MSZ7S4_0w"}    0
# /repos/preferences:{"post":"iNJX745XYh_3eHmuSThrQNv6CKGDFAwyUoLKfCEazXfuFUoO55vUFTGPpbjpdUZ8NjZNG2li_9K1x8UexXvpng"}}}                                               0
# title:"2023-Tutorials/data/states_edu.csv at b79043e8eed2e57606c2aab37ec1f867a8b429e6 · MichiganDataScienceTeam/2023-Tutorials"}                                     0
# SUPPORT_SERVICES_EXPENDITURE_PER_STUDENT                                                                                                                             0
# Length: 43041, dtype: int64

# %%
# this will print the number of valid values in each column
df.notna().sum()
# Out:
# {"payload":{"allShortcutsEnabled":true                                                                                                                               0
# fileTree:{"data":{"items":[{"name":"cereal.csv"                                                                                                                      0
# path:"data/cereal.csv"                                                                                                                                               0
# contentType:"file"}                                                                                                                                                  0
# {"name":"starbucks.csv"                                                                                                                                              0
#                                                                                                                                                                     ..
# copilotAccessAllowed:false                                                                                                                                           0
# csrf_tokens:{"/MichiganDataScienceTeam/2023-Tutorials/branches":{"post":"Bcc4XB4ZDzfnCDelbkaGVdo58wCq_Fr1Y9yBWT0vIjEd1RuHvOs-1M-K29uWOqOlhV9r3dPRvjzb7MSZ7S4_0w"}    0
# /repos/preferences:{"post":"iNJX745XYh_3eHmuSThrQNv6CKGDFAwyUoLKfCEazXfuFUoO55vUFTGPpbjpdUZ8NjZNG2li_9K1x8UexXvpng"}}}                                               0
# title:"2023-Tutorials/data/states_edu.csv at b79043e8eed2e57606c2aab37ec1f867a8b429e6 · MichiganDataScienceTeam/2023-Tutorials"}                                     0
# SUPPORT_SERVICES_EXPENDITURE_PER_STUDENT                                                                                                                             0
# Length: 43041, dtype: int64

# %%
# notice that pandas will often ignore missing values by default
df.count()
# Out:
# {"payload":{"allShortcutsEnabled":true                                                                                                                               0
# fileTree:{"data":{"items":[{"name":"cereal.csv"                                                                                                                      0
# path:"data/cereal.csv"                                                                                                                                               0
# contentType:"file"}                                                                                                                                                  0
# {"name":"starbucks.csv"                                                                                                                                              0
#                                                                                                                                                                     ..
# copilotAccessAllowed:false                                                                                                                                           0
# csrf_tokens:{"/MichiganDataScienceTeam/2023-Tutorials/branches":{"post":"Bcc4XB4ZDzfnCDelbkaGVdo58wCq_Fr1Y9yBWT0vIjEd1RuHvOs-1M-K29uWOqOlhV9r3dPRvjzb7MSZ7S4_0w"}    0
# /repos/preferences:{"post":"iNJX745XYh_3eHmuSThrQNv6CKGDFAwyUoLKfCEazXfuFUoO55vUFTGPpbjpdUZ8NjZNG2li_9K1x8UexXvpng"}}}                                               0
# title:"2023-Tutorials/data/states_edu.csv at b79043e8eed2e57606c2aab37ec1f867a8b429e6 · MichiganDataScienceTeam/2023-Tutorials"}                                     0
# SUPPORT_SERVICES_EXPENDITURE_PER_STUDENT                                                                                                                             0
# Length: 43041, dtype: int64

# %% [markdown]
# One way we can deal with missing values is by dropping rows with any null value.

# %%
# by default, dropna will remove all rows with at least 1 nan
df.dropna()
# Out:
# Empty DataFrame
# Columns: [{"payload":{"allShortcutsEnabled":true, fileTree:{"data":{"items":[{"name":"cereal.csv", path:"data/cereal.csv", contentType:"file"}, {"name":"starbucks.csv", path:"data/starbucks.csv", contentType:"file"}.1, {"name":"states_edu.csv", path:"data/states_edu.csv", contentType:"file"}], totalCount:3}, :{"items":[{"name":"Data-Visualization", path:"Data-Visualization", contentType:"directory"}, {"name":"Optional Challenges", path:"Optional Challenges", contentType:"directory"}.1, {"name":"data", path:"data", contentType:"directory"}.2, {"name":"tutorial0", path:"tutorial0", contentType:"directory"}.3, {"name":"tutorial1", path:"tutorial1", contentType:"directory"}.4, {"name":".gitignore", path:".gitignore", contentType:"file"}.2, {"name":"README.md", path:"README.md", contentType:"file"}.3, {"name":"requirements.txt", path:"requirements.txt", contentType:"file"}].1, totalCount:8}}, fileTreeProcessingTime:10.429732000000001, foldersToFetch:[], reducedMotionEnabled:"system", repo:{"id":529869678, defaultBranch:"main", name:"2023-Tutorials", ownerLogin:"MichiganDataScienceTeam", currentUserCanPush:false, isFork:false, isEmpty:false, createdAt:"2022-08-28T09:25:18.000-04:00", ownerAvatar:"https://avatars.githubusercontent.com/u/15266139?v=4", public:true, private:false, isOrgOwned:true}, symbolsExpanded:false, treeExpanded:true, refInfo:{"name":"b79043e8eed2e57606c2aab37ec1f867a8b429e6", listCacheKey:"v0:1705247162.0", canEdit:false, refType:"tree", currentOid:"b79043e8eed2e57606c2aab37ec1f867a8b429e6"}, path:"data/states_edu.csv".1, currentUser:{"id":153706586, login:"JqWu11", userEmail:"jqwu@umich.edu"}, blob:{"rawLines":null, stylingDirectives:null, csv:[["PRIMARY_KEY", STATE, YEAR, ENROLL_ALL_EST, TOTAL_REVENUE, FEDERAL_REVENUE, STATE_REVENUE, LOCAL_REVENUE, TOTAL_EXPENDITURE, INSTRUCTION_EXPENDITURE, SUPPORT_SERVICES_EXPENDITURE, OTHER_EXPENDITURE, CAPITAL_OUTLAY_EXPENDITURE, ENROLL_PREK, ENROLL_KINDER, ENROLL_4, ENROLL_8, ENROLL_12, ENROLL_PRIMARY, ENROLL_HS, ENROLL_ALL, AVG_MATH_4_SCORE, AVG_MATH_8_SCORE, AVG_READING_4_SCORE, AVG_READING_8_SCORE], ["1992_ALABAMA", ALABAMA, 1992, null, 2678885.0, 304177.0, 1659028.0, 715680.0, 2653798.0, 1481703.0, 735036.0, ...]
# Index: []
#
# [0 rows x 43041 columns]

# %% [markdown]
# Dropping rows with any nan leaves us only 355 rows -- do we actually need all our data to be complete? Which rows are actually important?
#
# That depends on what you want to do with the data!
#
# For the purpose of this tutorial, let's say we are particularly interested in 8th grade reading scores.

# %%
# In that case, we will drop all the rows where the 8th grading reading score is missing
df.dropna(subset=['AVG_READING_8_SCORE'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/77/rm_g73911n9d55svjj04kgfh0000gn/T/ipykernel_68689/3736388246.py in ?()
#       1 # In that case, we will drop all the rows where the 8th grading reading score is missing
# ----> 2 df.dropna(subset=['AVG_READING_8_SCORE'], inplace=True)
#
# /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6650             ax = self._get_axis(agg_axis)
#    6651             indices = ax.get_indexer_for(subset)
#    6652             check = indices == -1
#    6653             if check.any():
# -> 6654                 raise KeyError(np.array(subset)[check].tolist())
#    6655             agg_obj = self.take(indices, axis=agg_axis)
#    6656
#    6657         if thresh is not lib.no_default:
#
# KeyError: ['AVG_READING_8_SCORE']

# %% [markdown]
# Another way of dealing with missing values is filling them in with a value that is representative of other values in the column. Medians and means are common choices and are suited to different scenarios.

# %% [markdown]
# In our data, we have two columns representing total student enrollment: `ENROLL_ALL_EST` and `ENROLL_ALL`. We also have enrollment data divided by school group. Let's see if we can use them to fill each other in.

# %%
df["ENROLL_ALL"].isna().sum()
# Out:
# 0

# %%
# first let's check if the individual enrollments actually sum up to total enrollment
(df["ENROLL_ALL"]-df["ENROLL_PREK"]-df["ENROLL_KINDER"]-df["ENROLL_PRIMARY"]-df["ENROLL_HS"]).describe()
# Out:
# count       0
# unique      0
# top       NaN
# freq      NaN
# dtype: object

# %%
# enrollment differences as a percent
((df["ENROLL_ALL"]-df["ENROLL_PREK"]-df["ENROLL_KINDER"]-df["ENROLL_PRIMARY"]-df["ENROLL_HS"])/df["ENROLL_ALL"]*100).describe()
# Out:
# count       0
# unique      0
# top       NaN
# freq      NaN
# dtype: object

# %% [markdown]
# Looks like the individual enrollments do sum up to the total enrollment in most cases! And even when they don't, the deviation is usually not drastic.
#
# This is not a terrible way to estimate total enrollment.

# %%
df['ENROLL_ALL'] = df['ENROLL_ALL'].fillna(df["ENROLL_PREK"]+df["ENROLL_PRIMARY"]+df["ENROLL_HS"])

# %%
# this didn't actually do anything!
df["ENROLL_ALL"].isna().sum()
# Out:
# 0

# %%
# turns out, data missing ENROLL_ALL is also missing all other enrollment data
df[df["ENROLL_ALL"].isna()][['ENROLL_PREK','ENROLL_PRIMARY','ENROLL_HS','ENROLL_ALL_EST']].notna().any()
# Out:
# ENROLL_PREK       False
# ENROLL_PRIMARY    False
# ENROLL_HS         False
# ENROLL_ALL_EST    False
# dtype: bool

# %%
# but there are rows with enrollment estimates
df[df.ENROLL_ALL_EST.isna()]["ENROLL_ALL"].notna().sum()
# Out:
# 0

# %%
# let's see if we can fill these in
((df["ENROLL_ALL"] - df["ENROLL_ALL_EST"])/df["ENROLL_ALL"]).describe()
# Out:
# count       0
# unique      0
# top       NaN
# freq      NaN
# dtype: object

# %%
# since the average error between estimated and actual enrollment is ~2%, I'm going to go ahead and fill in the missing estimates
df["ENROLL_ALL_EST"] = df["ENROLL_ALL_EST"].fillna(df["ENROLL_ALL"])

# %% [markdown]
# What we just did was data cleanup! Most data scientists will tell you that data cleanup and preprocessing will take >60% of the total time for a given project... We just gave you a small teaser here but you'll be seeing a lot more of it :)

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# Something else you'll see a lot of is feature engineering. In this step, we manipulate the data set so the data is can be used for analysis more readily.
#
# Here are some common methods of modifying features:
#
# * Standardization
# >helps some models account for different magnitude features, e.g. revenue is ~10x bigger than enrollment on average, but that doesn't make it more important
# * Binning
# >reduces the importance of small differences in data, e.g. exact enrollment probably doesn't matter, but there may still be a difference between 'small', 'medium', and 'large' schools
# * Combining features
# >combinations of features may matter more than the features on their own, e.g. educational expenditure as a percent of total expenditure is more informative about a state's priorities (states aren't all the same size)

# %% [markdown]
# In this case, we know our data is on the state level and also longitudinal (over time).
#
# This format introduces some complications. For example, the state of California will obviously spend more than New Jersey becuase they have more people... how can we account for this?

# %%
# let's create a new column which represents expenditure per student
df['SUPPORT_SERVICES_EXPENDITURE_PER_STUDENT'] = df['SUPPORT_SERVICES_EXPENDITURE'] / df['ENROLL_ALL']

# %% [markdown]
# ## EDA

# %% [markdown]
# Now let's do some EDA (exploratory data analysis)!
#
# You should always perform EDA when you are beginning to work with a new dataset. EDA will reveal irregularities and interesting patterns in the data, both of which are hugely informative for your work later.

# %% [markdown]
# The first step in EDA is usually looking at the variable of interest in isolation. What's its distribution? How has it changed over time?

# %%
# note - this test is scored out of 500 according to the NAEP website
df.AVG_READING_8_SCORE.plot.hist(title="Distribution of 8th Grade Reading Scores", edgecolor="black")
# Out:
# <Axes: title={'center': 'Distribution of 8th Grade Reading Scores'}, ylabel='Frequency'>

# %%
df.groupby('YEAR')["AVG_READING_8_SCORE"].mean().plot()
plt.ylabel('SCORE')
plt.title('8th Grade Reading Score Over Time')
# Out:
# Text(0.5, 1.0, '8th Grade Reading Score Over Time')

# %% [markdown]
# Then, we can investigate the relationship between the variable of interest and other (potentially) relevant variables.

# %%
df.plot.scatter(x='ENROLL_8', y='AVG_READING_8_SCORE', alpha=0.6)
plt.xlabel('8th Grade Enrollment')
plt.ylabel('8th Grade Reading Score')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in get_loc(self, key)
#    3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
# -> 3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ENROLL_8'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.plot.scatter(x='ENROLL_8', y='AVG_READING_8_SCORE', alpha=0.6)
#       2 plt.xlabel('8th Grade Enrollment')
#       3 plt.ylabel('8th Grade Reading Score')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/plotting/_core.py:1748, in scatter(self, x, y, s, c, **kwargs)
#    1663 def scatter(
#    1664     self,
#    1665     x: Hashable,
#    (...)
#    1669     **kwargs,
#    1670 ) -> PlotAccessor:
#    1671     """
#    1672     Create a scatter plot with varying marker point size and color.
#    1673
#    1674     The coordinates of each point are defined by two dataframe columns and
#    1675     filled circles are used to represent each point. This kind of plot is
#    1676     useful to see complex correlations between two variables. Points could
#    1677     be for instance natural 2D coordinates like longitude and latitude in
#    1678     a map or, in general, any pair of metrics that can be plotted against
#    1679     each other.
#    1680
#    1681     Parameters
#    1682     ----------
#    1683     x : int or str
#    1684         The column name or column position to be used as horizontal
#    1685         coordinates for each point.
#    1686     y : int or str
#    1687         The column name or column position to be used as vertical
#    1688         coordinates for each point.
#    1689     s : str, scalar or array-like, optional
#    1690         The size of each point. Possible values are:
#    1691
#    1692         - A string with the name of the column to be used for marker's size.
#    1693
#    1694         - A single scalar so all points have the same size.
#    1695
#    1696         - A sequence of scalars, which will be used for each point's size
#    1697           recursively. For instance, when passing [2,14] all points size
#    1698           will be either 2 or 14, alternatively.
#    1699
#    1700     c : str, int or array-like, optional
#    1701         The color of each point. Possible values are:
#    1702
#    1703         - A single color string referred to by name, RGB or RGBA code,
#    1704           for instance 'red' or '#a98d19'.
#    1705
#    1706         - A sequence of color strings referred to by name, RGB or RGBA
#    1707           code, which will be used for each point's color recursively. For
#    1708           instance ['green','yellow'] all points will be filled in green or
#    1709           yellow, alternatively.
#    1710
#    1711         - A column name or position whose values will be used to color the
#    1712           marker points according to a colormap.
#    1713
#    1714     **kwargs
#    1715         Keyword arguments to pass on to :meth:`DataFrame.plot`.
#    1716
#    1717     Returns
#    1718     -------
#    1719     :class:`matplotlib.axes.Axes` or numpy.ndarray of them
#    1720
#    1721     See Also
#    1722     --------
#    1723     matplotlib.pyplot.scatter : Scatter plot using multiple input data
#    1724         formats.
#    1725
#    1726     Examples
#    1727     --------
#    1728     Let's see how to draw a scatter plot using coordinates from the values
#    1729     in a DataFrame's columns.
#    1730
#    1731     .. plot::
#    1732         :context: close-figs
#    1733
#    1734         >>> df = pd.DataFrame([[5.1, 3.5, 0], [4.9, 3.0, 0], [7.0, 3.2, 1],
#    1735         ...                    [6.4, 3.2, 1], [5.9, 3.0, 2]],
#    1736         ...                   columns=['length', 'width', 'species'])
#    1737         >>> ax1 = df.plot.scatter(x='length',
#    1738         ...                       y='width',
#    1739         ...                       c='DarkBlue')
#    1740
#    1741     And now with the color determined by a column as well.
#    1742
#    1743     .. plot::
#    1744         :context: close-figs
#    1745
#    1746         >>> ax2 = df.plot.scatter(x='length',
#    1747         ...                       y='width',
# -> 1748         ...                       c='species',
#    1749         ...                       colormap='viridis')
#    1750     """
#    1751     return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/plotting/_core.py:975, in __call__(self, *args, **kwargs)
#     972     kwargs["reuse_plot"] = True
#     974 if kind in self._dataframe_kinds:
# --> 975     if isinstance(data, ABCDataFrame):
#     976         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     977     else:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/plotting/_matplotlib/core.py:453, in MPLPlot.generate(self)
#     451 self._compute_plot_data()
#     452 self._setup_subplots()
# --> 453 self._make_plot()
#     454 self._add_table()
#     455 self._make_legend()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/plotting/_matplotlib/core.py:1267, in ScatterPlot._make_plot(self)
#    1264 else:
#    1265     label = None
#    1266 scatter = ax.scatter(
# -> 1267     data[x].values,
#    1268     data[y].values,
#    1269     c=c_values,
#    1270     label=label,
#    1271     cmap=cmap,
#    1272     norm=norm,
#    1273     **self.kwds,
#    1274 )
#    1275 if cb:
#    1276     cbar_label = c if c_is_column else ""
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4090, in __getitem__(self, key)
#    4082     elif (
#    4083         is_list_like(value)
#    4084         and not self.columns.is_unique
#    4085         and 1 < len(self.columns.get_indexer_for([key])) == len(value)
#    4086     ):
#    4087         # Column to set is duplicated
#    4088         self._setitem_array([key], value)
#    4089     else:
# -> 4090         # set column
#    4091         self._set_item(key, value)
#    4093 def _setitem_slice(self, key: slice, value) -> None:
#    4094     # NB: we can't just use self.loc[key] = value because that
#    4095     #  operates on labels and we need to operate positional for
#    4096     #  backwards-compat, xref GH#31469
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3809, in get_loc(self, key)
#    3803         self._check_indexing_error(key)
#    3804         raise
#    3806 _index_shared_docs[
#    3807     "get_indexer"
#    3808 ] = """
# -> 3809     Compute indexer and mask for new index given the current index.
#    3810
#    3811     The indexer should be then used as an input to ndarray.take to align the
#    3812     current data to the new index.
#    3813
#    3814     Parameters
#    3815     ----------
#    3816     target : %(target_klass)s
#    3817     method : {None, 'pad'/'ffill', 'backfill'/'bfill', 'nearest'}, optional
#    3818         * default: exact matches only.
#    3819         * pad / ffill: find the PREVIOUS index value if no exact match.
#    3820         * backfill / bfill: use NEXT index value if no exact match
#    3821         * nearest: use the NEAREST index value if no exact match. Tied
#    3822           distances are broken by preferring the larger index value.
#    3823     limit : int, optional
#    3824         Maximum number of consecutive labels in ``target`` to match for
#    3825         inexact matches.
#    3826     tolerance : optional
#    3827         Maximum distance between original and new labels for inexact
#    3828         matches. The values of the index at the matching locations must
#    3829         satisfy the equation ``abs(index[indexer] - target) <= tolerance``.
#    3830
#    3831         Tolerance may be a scalar value, which applies the same tolerance
#    3832         to all values, or list-like, which applies variable tolerance per
#    3833         element. List-like includes list, tuple, array, Series, and must be
#    3834         the same size as the index and its dtype must exactly match the
#    3835         index's type.
#    3836
#    3837     Returns
#    3838     -------
#    3839     np.ndarray[np.intp]
#    3840         Integers from 0 to n - 1 indicating that the index at these
#    3841         positions matches the corresponding target values. Missing values
#    3842         in the target are marked by -1.
#    3843     %(raises_section)s
#    3844     Notes
#    3845     -----
#    3846     Returns -1 for unmatched values, for further explanation see the
#    3847     example below.
#    3848
#    3849     Examples
#    3850     --------
#    3851     >>> index = pd.Index(['c', 'a', 'b'])
#    3852     >>> index.get_indexer(['a', 'b', 'x'])
#    3853     array([ 1,  2, -1])
#    3854
#    3855     Notice that the return value is an array of locations in ``index``
#    3856     and ``x`` is marked by -1, as it is not in ``index``.
#    3857     """
#    3859 @Appender(_index_shared_docs["get_indexer"] % _index_doc_kwargs)
#    3860 @final
#    3861 def get_indexer(
#    (...)
#    3866     tolerance=None,
#    3867 ) -> npt.NDArray[np.intp]:
#    3868     method = clean_reindex_fill_method(method)
#
# KeyError: 'ENROLL_8'

# %%
df.plot.scatter(x='STATE_REVENUE', y='AVG_READING_8_SCORE', alpha=0.6)
plt.xlabel('State Revenue')
plt.ylabel('8th Grade Reading Score')
# Out:
# Text(0, 0.5, '8th Grade Reading Score')

# %%
df.plot.scatter(x='INSTRUCTION_EXPENDITURE', y='AVG_READING_8_SCORE', alpha=0.6)
plt.xlabel('Instruction Expenditure')
plt.ylabel('8th Grade Reading Score')
# Out:
# Text(0, 0.5, '8th Grade Reading Score')

# %%
df.plot.scatter(x='AVG_READING_4_SCORE', y='AVG_READING_8_SCORE', alpha=0.8)
# Out:
# <Axes: xlabel='AVG_READING_4_SCORE', ylabel='AVG_READING_8_SCORE'>

# %%
df.plot.scatter(x='AVG_MATH_8_SCORE', y='AVG_READING_8_SCORE', alpha=0.8)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'AVG_READING_8_SCORE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df.plot.scatter(x='AVG_MATH_8_SCORE', y='AVG_READING_8_SCORE', alpha=0.8)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/plotting/_core.py:1748, in PlotAccessor.scatter(self, x, y, s, c, **kwargs)
#    1660 def scatter(
#    1661     self,
#    1662     x: Hashable,
#    (...)
#    1666     **kwargs,
#    1667 ) -> PlotAccessor:
#    1668     """
#    1669     Create a scatter plot with varying marker point size and color.
#    1670
#    (...)
#    1746         ...                       colormap='viridis')
#    1747     """
# -> 1748     return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/plotting/_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     973 if kind in self._dataframe_kinds:
#     974     if isinstance(data, ABCDataFrame):
# --> 975         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     976     else:
#     977         raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/plotting/_matplotlib/core.py:501, in MPLPlot.generate(self)
#     499 self._compute_plot_data()
#     500 fig = self.fig
# --> 501 self._make_plot(fig)
#     502 self._add_table()
#     503 self._make_legend()
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/plotting/_matplotlib/core.py:1347, in ScatterPlot._make_plot(self, fig)
#    1343 else:
#    1344     label = None
#    1345 scatter = ax.scatter(
#    1346     data[x].values,
# -> 1347     data[y].values,
#    1348     c=c_values,
#    1349     label=label,
#    1350     cmap=cmap,
#    1351     norm=norm,
#    1352     s=self.s,
#    1353     **self.kwds,
#    1354 )
#    1355 if cb:
#    1356     cbar_label = c if c_is_column else ""
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:3809, in Index.get_loc(self, key)
#    3804     if isinstance(casted_key, slice) or (
#    3805         isinstance(casted_key, abc.Iterable)
#    3806         and any(isinstance(x, slice) for x in casted_key)
#    3807     ):
#    3808         raise InvalidIndexError(key)
# -> 3809     raise KeyError(key) from err
#    3810 except TypeError:
#    3811     # If we have a listlike key, _check_indexing_error will raise
#    3812     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3813     #  the TypeError.
#    3814     self._check_indexing_error(key)
#
# KeyError: 'AVG_READING_8_SCORE'

# %% [markdown]
# It seems 4th grade reading score and 8th grade math score are strongly correlated with 8th grade reading score. All the other variables that we investigated have weak or no correlation with 8th grade reading score.

# %% [markdown]
# So now that we know a bit about the data, what do we want to do with it? How am I going to frame this as a _machine learning_ project?

# %% [markdown]
# ## Quick Intro to Machine Learning!

# %% [markdown]
# Unfortunately, we can't teach machine learning in single tutorial. For this tutorial, we're going to practice a simple _supervised learning_ problem.

# %% [markdown]
# **Machine learning workflow:**
# <img src=https://miro.medium.com/proxy/1*KzmIUYPmxgEHhXX7SlbP4w.jpeg width=500></img>

# %% [markdown]
# **Supervised learning:**
# <img src=https://miro.medium.com/max/1050/1*-fniNC8gWI34qLAiBzgGZA.png width=800></img>

# %% [markdown]
# We have established that we are interested in 8th grade reading scores, so I want to make that my response variable (i.e. what I'm trying to predict).
#
# Based on the EDA, I think that `ENROLL_8`, `AVG_MATH_8_SCORE`, and `AVG_READING_4_SCORE` would be interesting predictors to look at, so I will pick these as my input features.

# %% [markdown]
# **Regression**

# %%
# test_train_split randomly splits the data into two parts -- 
# one for training the model (it uses this data to learn patterns)
# and one for testing the model (to make sure it performs well on data it hasn't seen before)
from sklearn.model_selection import train_test_split

# %%
# X is commonly used to denote the input data
# y is used for the response / output data
X = df[['ENROLL_8','AVG_MATH_8_SCORE','AVG_READING_4_SCORE']].dropna()
y = df.loc[X.index]['AVG_READING_8_SCORE']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 3
#       1 # X is commonly used to denote the input data
#       2 # y is used for the response / output data
# ----> 3 X = df[['ENROLL_8','AVG_MATH_8_SCORE','AVG_READING_4_SCORE']].dropna()
#       4 y = df.loc[X.index]['AVG_READING_8_SCORE']
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4096, in __getitem__(self, key)
#    4089     else:
#    4090         # set column
#    4091         self._set_item(key, value)
#    4093 def _setitem_slice(self, key: slice, value) -> None:
#    4094     # NB: we can't just use self.loc[key] = value because that
#    4095     #  operates on labels and we need to operate positional for
# -> 4096     #  backwards-compat, xref GH#31469
#    4097     self._check_setitem_copy()
#    4098     self.iloc[key] = value
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:6199, in _get_indexer_strict(self, key, axis_name)
#    6193 @overload
#    6194 def _get_indexer_non_comparable(
#    6195     self, target: Index, method, unique: bool = True
#    6196 ) -> npt.NDArray[np.intp] | tuple[npt.NDArray[np.intp], npt.NDArray[np.intp]]:
#    6197     ...
# -> 6199 @final
#    6200 def _get_indexer_non_comparable(
#    6201     self, target: Index, method, unique: bool = True
#    6202 ) -> npt.NDArray[np.intp] | tuple[npt.NDArray[np.intp], npt.NDArray[np.intp]]:
#    6203     """
#    6204     Called from get_indexer or get_indexer_non_unique when the target
#    6205     is of a non-comparable dtype.
#    (...)
#    6224         If doing an inequality check, i.e. method is not None.
#    6225     """
#    6226     if method is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:6251, in _raise_if_missing(self, key, indexer, axis_name)
#    6247     return self.is_unique
#    6249 _requires_unique_msg = "Reindexing only valid with uniquely valued Index objects"
# -> 6251 @final
#    6252 def _maybe_promote(self, other: Index) -> tuple[Index, Index]:
#    6253     """
#    6254     When dealing with an object-dtype Index and a non-object Index, see
#    6255     if we can upcast the object-dtype one to improve performance.
#    6256     """
#    6258     if isinstance(self, ABCDatetimeIndex) and isinstance(other, ABCDatetimeIndex):
#
# KeyError: "['ENROLL_8'] not in index"

# %%
# We also need to make sure there is no NaN in y
# This time, we will fill the NaN with the median of y 
# We prefer median to mean because EDA reveals that the response variable is left-skewed. Therefore, the mean may not represent the data very well
y.fillna(y.median(), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 # We also need to make sure there is no NaN in y
#       2 # This time, we will fill the NaN with the median of y
#       3 # We prefer median to mean because EDA reveals that the response variable is left-skewed. Therefore, the mean may not represent the data very well
# ----> 4 y.fillna(y.median(), inplace=True)
#
# NameError: name 'y' is not defined

# %%
# the test_size parameter defines what % of data is set aside for testing, 70 / 30 and 80 / 20 split are both typical
# we don't have a huge data set but we still want to have a decently sized testing set
# so we are using a 70 / 30 train / test split. 
# setting random_state explicitly ensures that I get the same results each time I run the code
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=0)

# %% [markdown]
# Now to create and train a model! For simplicity, I'm going to use `sklearn`'s `LinearRegression` class.

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
# fit is essentially the word sklearn uses for training
model.fit(X_train, y_train)

# %% [markdown]
# What we are doing here is called _least squares linear regression_.
#
# Let's say there are $k$ input variables, named $x_1$ through $x_k$ (here, I have $k=3$, $x_1$ = `ENROLL_8`, $x_2$ = `AVG_MATH_8_SCORE`, etc.)
#
# The model is trying to find the one equation of the form that minimizes some error measure. In this case, that measure is residual sum of squares ([RSS](https://en.wikipedia.org/wiki/Residual_sum_of_squares)):
#
# $y_{predicted} = intercept + \beta_0x_1 + \beta_1x_2 + ... + \beta_kx_k$ where $\beta_i$ are the coefficients.
#
# Notice there are exactly $k$ coefficients. We can interpret each coefficient by holding all other variables constant (_ceteris paribus_, if you are feeling fancy).
#
# For example, if $\beta_2=0.2$, we say "with all other variables held constant, a 1 point increase in average grade 8 math score results in a 0.2-point increase in reading score".

# %%
# You can see the intercepts and coefficients the model generates
print(model.intercept_)
print(model.coef_)

# %%
# R^2 value describes how well a linear model fits the data
# It ranges between 0 and 1
# There are many caveats to R^2 but it is a good starting point
model.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 4
#       1 # R^2 value describes how well a linear model fits the data
#       2 # It ranges between 0 and 1
#       3 # There are many caveats to R^2 but it is a good starting point
# ----> 4 model.score(X_test, y_test)
#
# NameError: name 'model' is not defined

# %%
# mean error
np.mean(model.predict(X_test)-y_test)

# %%
# mean absolute error
np.mean(np.abs(model.predict(X_test)-y_test))

# %%
# root mean squared error -- penalizes large errors
np.mean((model.predict(X_test)-y_test)**2)**0.5

# %% [markdown]
# Now we can take a look at the model's predictions and how it differs from the actual data.

# %%
col_name = 'AVG_MATH_8_SCORE'

f = plt.figure(figsize=(12,6))
plt.scatter(X_train[col_name], y_train, color = "red")
plt.scatter(X_train[col_name], model.predict(X_train), color = "green")

plt.legend(['True Training','Predicted Training'])
plt.xlabel(col_name)
plt.ylabel('Reading 8 score')
plt.title("Model Behavior On Training Set")

# %%
col_name = 'AVG_MATH_8_SCORE'

f = plt.figure(figsize=(12,6))
plt.scatter(X_test[col_name], y_test, color = "blue")
plt.scatter(X_test[col_name], model.predict(X_test), color = "black")

plt.legend(['True testing','Predicted testing'])
plt.xlabel(col_name)
plt.ylabel('Reading 8 score')
plt.title("Model Behavior on Testing Set")

# %% [markdown]
# It would seem that our model works fairly well on the training set and also generalizes nicely to the testing set. This is a good thing! Sometimes models will work *too* well on the training set that it does poorly on the testing set.
#
# This is known as overfitting. We will have a lot more to say about it in the future.
